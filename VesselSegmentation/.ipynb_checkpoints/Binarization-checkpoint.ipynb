# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import nibabel as nib

import torch
import torch.nn as nn
import torch.utils.data
import torchvision

from scipy.ndimage import zoom

import matplotlib.pyplot as plt
from torchvision.utils import make_grid

# %%
import sys

from multiprocessing import Process, Queue
from time import time, sleep

sys.path.insert(1, 'scripts')
from integral_volume3d import (Point3d, IntegralVol, IntegralVolTest)
from niblack3d import Niblack3d
from multyprocess_utils import MultuProcCalc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       6 sys.path.insert(1, 'scripts')
#       7 from integral_volume3d import (Point3d, IntegralVol, IntegralVolTest)
# ----> 8 from niblack3d import Niblack3d
#       9 from multyprocess_utils import MultuProcCalc
#
# File ~/repo/MSRepo/VesselSegmentation/scripts/niblack3d.py:2
#       1 import numpy as np
# ----> 2 import integral_volume as iv
#       4 class Niblack3d:
#       5     def __init__(self, vol=None, window_size=None, coef_k=None, coef_a=None):
#
# ModuleNotFoundError: No module named 'integral_volume'

# %%
#IntegralVolTest()
# Out:
# preprocess time 0.634925127029419
# numpy time 5.031959056854248
# integral vol time 0.0010342597961425781
# calculation error: 3.259629011154175e-09

# %%
brain_file = nib.load("data/sub-299_ses-20110422_desc-angio_N4bfc_brain_mask.nii.gz")

brain_vol = np.array(brain_file.dataobj)
print(brain_vol.shape)

##compressed
#brain_vol = zoom(brain_vol, (0.25, 0.25, 0.5))
#print(brain_vol.shape)
# Out:
# (512, 512, 140)

# %%
#new_vol = np.zeros((512, 512, 164))
#new_vol[:, :, 12:152] = brain_vol
#brain_vol = new_vol

# %%
def print_img(vol, axis, title= 'title', slice=None, cmap='hot'):
    global SHOW_SLICE
    #axis.set_xticks([])
    #axis.set_yticks([])
    axis.set_title(title)
    if slice is None:
        im = axis.imshow(vol[:, :, SHOW_SLICE], cmap=cmap)
    else: 
        im = axis.imshow(vol[:, :, slice], cmap=cmap)
    plt.colorbar(im)

# %%
SHOW_SLICE = 31

fig, ax = plt.subplots(1, 2, figsize=(8, 4))    
print_img(brain_vol, ax[0], 'slice', 50)    
print_img(brain_vol, ax[1], 'slice')

# %%
img_hist = np.histogram(brain_vol, bins=100, range=(brain_vol.min(), brain_vol.max()))

# %%
counts, bins = img_hist

plt.subplots(figsize=(4, 2)) 
plt.hist(bins[:-1], bins, weights=counts, range=(0, 500))
1
# Out:
# 1

# %%
plt.subplots(figsize=(4, 2))    
plt.hist(bins[:-1], 100, weights=counts, range=(250, 500))
1
# Out:
# 1

# %%
def proc(out_queue, algorithm, process_data):
    out_vol = algorithm.binarize(process_data["edges"])
    process_data.update({"out_vol" : out_vol})
    out_queue.put(process_data) 

    
def MultuProcCalc(algorithm, num_workers=1):
    out_queue = Queue()
    procs = []
    
    process_data = generate_process_data(algorithm.vol.shape, num_workers)
    
    for i in range(num_workers):
        p = Process(target = proc, args = (out_queue, algorithm, process_data[i]))  
        p.start()
        procs.append(p)
        
    bin_vol = np.zeros_like(algorithm.vol)
    for i in range(num_workers):
        process_data = out_queue.get()
        e = process_data["edges"]
        bin_vol[e[0][0]:e[0][1],
                e[1][0]:e[1][1],
                e[2][0]:e[2][1]] = process_data["out_vol"]
    
    for p in procs:
        p.join()
    
    return(bin_vol)

# %%
window_size = (25, 25, 9)
coef_k = 1
coef_a = 100
Niblack = Niblack3d(vol=brain_vol,
                    window_size=window_size,
                    coef_k=coef_k, 
                    coef_a=coef_a)

# %%
start = time()
bin_vol = MultuProcCalc(Niblack, num_workers=8)
print("spend:", time() - start)
# Out:
# spend: 31.486979961395264

# %%
for idx in range(0, 30, 5):    
    SHOW_SLICE = idx

    fig, ax = plt.subplots(1, 2, figsize=(19, 7))    
    print_img(bin_vol, ax[0], 'niblack', cmap='gray')    
    print_img(brain_vol, ax[1], 'brain')

# %%
#sigmas = np.array(sigmas)
#sigmas_hist = np.histogram(sigmas, bins=100, range=(sigmas.min(), sigmas.max()))

#counts, bins = sigmas_hist

#plt.subplots(figsize=(4, 2)) 
#plt.hist(bins[1:-1], bins[1:], weights=counts[1:])

# %%
def save_vol_as_nii(numpy_arr, loaded_file, path_to_save):
    empty_header = nib.Nifti1Header()
    Nifti1Image = nib.Nifti1Image(numpy_arr, loaded_file.affine, empty_header)
    nib.save(Nifti1Image, path_to_save)

# %%
path_to_save_brain = 'seg_data/brain_vol_compressed1.nii.gz'
path_to_save_seg = 'seg_data/seg_vol_compressed1.nii.gz'

save_vol_as_nii(test_vol, brain_file, path_to_save_brain)
save_vol_as_nii(bin_vol, brain_file, path_to_save_seg)

# %%
def calc_mu(integr_vol, window_size, p1, p2):
    mu = integr_vol.calculate_sum(p1, p2)
    mu *= (1/window_size[0]/window_size[1]/window_size[2])
    return mu
    
def calc_T(integr, integr_sq, w_s, f, s):

    mu = calc_mu(integr, window_size, f, s)
    mu_sq = calc_mu(integr_sq, window_size, f, s)

    sigma = mu_sq - mu**2
    eps = 1e-6
    sigma += eps

    if sigma<0:
        print(i, j, k, ": sigma<0")
        sigma = 0
    #assert sigma >= 0

    sigma = sigma**0.5
    T = mu + (coef_k * sigma) + coef_a
    return(T, sigma)

def niblack3d(vol, window_size=(3, 3, 3), coef_k=0, coef_a=0): 
    bin_vol = np.zeros_like(vol, dtype=bool)

    sigmas = []
    
    for i in range(0, integr.integral_vol.shape[0]-1):
        for j in range(0, integr.integral_vol.shape[1]-1):
            for k in range(0, integr.integral_vol.shape[2]-1):

                w_s = (window_size[0]//2, window_size[1]//2, window_size[2]//2)
                
                f = Point3d(i-w_s[0], j-w_s[1], k-w_s[2]).edit_to_vol(bin_vol)
                s = Point3d(i+w_s[0], j+w_s[1], k+w_s[2]).edit_to_vol(bin_vol)
                
                T, sigma = calc_T(integr, integr_sq, w_s, f, s)
                
                sigmas.append(sigma)
                
                if vol[i, j, k]>=T:
                    bin_vol[i, j, k] = 1  
                    
    return(bin_vol, sigmas)

# %%
window_size = (11, 11, 5)
coef_k = 0.2
coef_a = 125
bin_vol, sigmas = niblack3d(test_vol, window_size=window_size, coef_k=coef_k, coef_a=coef_a)

# %%
sigmas = np.array(sigmas)
sigmas_hist = np.histogram(sigmas, bins=100, range=(sigmas.min(), sigmas.max()))

counts, bins = sigmas_hist

plt.subplots(figsize=(4, 2)) 
plt.hist(bins[1:-1], bins[1:], weights=counts[1:])
1
# Out:
# 1

# %%
SHOW_SLICE = 10

fig, ax = plt.subplots(1, 2, figsize=(12, 6))    
print_img(bin_vol, ax[0], 'niblack')    
print_img(test_vol, ax[1], 'brain')
